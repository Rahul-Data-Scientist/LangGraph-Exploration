# %%
# Workflow of previous notebook did what it supposed to but in this notebook, we are going to add extra constraints and details in our pydantic schemas to improve the quality of the final product i.e., the blog.

# %%
from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage

import operator
from dotenv import load_dotenv
from typing import Annotated, List, TypedDict, Literal
from pydantic import BaseModel, Field
import operator
from pathlib import Path

# %%
class Task(BaseModel):
    id: int
    title: str
    goal: Annotated[str, Field(
        ...,
        description = "One sentence describing what the reader should be able to do/understand after this section."
    )]
    bullets: Annotated[List[str], Field(
        ...,
        min_length=3,
        max_length=5,
        description="3-5 concrete, non-overlapping subpoints to cover in this section."
    )]
    target_words: Annotated[int, Field(
        ...,
        description="Target word count for this section (120-450)."
    )]
    section_type: Annotated[Literal["intro", "core", "examples", "checklist", "common_mistakes", "conclusion"], Field(
        ...,
        description="Use 'common_mistakes' exactly once in the plan."
    )]

# %%
class Plan(BaseModel):
    blog_title: str
    audience: Annotated[str, Field(
        ...,
        description = "Who this blog is for"
    )]
    tone: Annotated[str, Field(
        ...,
        description = "Writing tone (e.g., practical, crisp)."
    )]
    tasks: List[Task]

# %%
class State(TypedDict):
    topic: str
    plan: Plan
    sections: Annotated[List[str], operator.add]
    final: str

# %%
llm = ChatOpenAI(model = "gpt-4.1-mini")

# %%
def orchestrator(state: State) -> dict:
    planner = llm.with_structured_output(Plan)
    plan = planner.invoke(
        [
            SystemMessage(
                content=(
                    "You are a senior technical writer and developer advocate. Your job is to produce a "
                    "highly actionable outline for a technical blog post.\n\n"
                    "Hard requirements:\n"
                    "- Create 5-7 sections (tasks) that fit a technical blog.\n"
                    "- Each section must include:\n"
                    "  1) goal (1 sentence: what the reader can do/understand after the section)\n"
                    "  2) 3-5 bullets that are concrete, specific, and non-overlapping\n"
                    "  3) target word count (120-450)\n"
                    "- Include EXACTLY ONE section with section_type='common_mistakes'.\n\n"
                    "Make it technical (not generic):\n"
                    "- Assume the reader is a developer; use correct terminology.\n"
                    "- Prefer design/engineering structure: problem → intuition → approach → implementation → "
                    "trade-offs → testing/observability → conclusion.\n"
                    "- Bullets must be actionable and testable (e.g., 'Show a minimal code snippet for X', "
                    "'Explain why Y fails under Z condition', 'Add a checklist for production readiness').\n"
                    "- Explicitly include at least ONE of the following somewhere in the plan (as bullets):\n"
                    "  * a minimal working example (MWE) or code sketch\n"
                    "  * edge cases / failure modes\n"
                    "  * performance/cost considerations\n"
                    "  * security/privacy considerations (if relevant)\n"
                    "  * debugging tips / observability (logs, metrics, traces)\n"
                    "- Avoid vague bullets like 'Explain X' or 'Discuss Y'. Every bullet should state what "
                    "to build/compare/measure/verify.\n\n"
                    "Ordering guidance:\n"
                    "- Start with a crisp intro and problem framing.\n"
                    "- Build core concepts before advanced details.\n"
                    "- Include one section for common mistakes and how to avoid them.\n"
                    "- End with a practical summary/checklist and next steps.\n\n"
                    "Output must strictly match the Plan schema."
                )
            ),
            HumanMessage(content=f"Topic: {state['topic']}")
        ]
    )

    return {"plan": plan}

# %%
def fanout(state: State):
    return [
        Send(
            "worker", 
            {"task": task, "plan": state['plan'], "topic": state['topic']}
        ) 
        for task in state['plan'].tasks
        ]

# %%
def worker(payload: dict) -> dict:
    task = payload["task"]
    topic = payload["topic"]
    plan = payload["plan"]

    bullets_text = "\n- " + "\n- ".join(task.bullets)

    section_md = llm.invoke(
        [
            SystemMessage(
    content=(
        "You are a senior technical writer and developer advocate. Write ONE section of a technical blog post in Markdown.\n\n"
        "Hard constraints:\n"
        "- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).\n"
        "- Stay close to the Target words (±15%).\n"
        "- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).\n\n"
        "Technical quality bar:\n"
        "- Be precise and implementation-oriented (developers should be able to apply it).\n"
        "- Prefer concrete details over abstractions: APIs, data structures, protocols, and exact terms.\n"
        "- When relevant, include at least one of:\n"
        "  * a small code snippet (minimal, correct, and idiomatic)\n"
        "  * a tiny example input/output\n"
        "  * a checklist of steps\n"
        "  * a diagram described in text (e.g., 'Flow: A -> B -> C')\n"
        "- Explain trade-offs briefly (performance, cost, complexity, reliability).\n"
        "- Call out edge cases / failure modes and what to do about them.\n"
        "- If you mention a best practice, add the 'why' in one sentence.\n\n"
        "Markdown style:\n"
        "- Start with a '## <Section Title>' heading.\n"
        "- Use short paragraphs, bullet lists where helpful, and code fences for code.\n"
        "- Avoid fluff. Avoid marketing language.\n"
        "- If you include code, keep it focused on the bullet being addressed.\n"
    )
)
,
            HumanMessage(
                content=(
                    f"Blog: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Topic: {topic}\n\n"
                    f"Section: {task.title}\n"
                    f"Section type: {task.section_type}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Bullets:{bullets_text}\n"
                )
            )
        ]
    ).content.strip()

    return {"sections": [section_md]}

# %%
def reducer(state: State) -> dict:

    title = state["plan"].blog_title
    body = "\n\n".join(state["sections"]).strip()
    
    final_md = f"# {title}\n\n{body}\n"

    # Save to file
    filename = "".join(c if c.isalnum() or c in (" ", "_", "-") else "" for c in title)
    filename = filename.strip().lower().replace(" ", "_").replace(":", "") + ".md"
    output_path = Path(filename)
    output_path.write_text(final_md, encoding="utf-8")

    return {"final": final_md}

# %%
from langgraph.checkpoint.memory import InMemorySaver

# %%
graph = StateGraph(State)

graph.add_node("orchestrator", orchestrator)
graph.add_node("worker", worker)
graph.add_node("reducer", reducer)

graph.add_edge(START, "orchestrator")
graph.add_conditional_edges("orchestrator", fanout, ['worker'])
graph.add_edge("worker", "reducer")
graph.add_edge("reducer", END)

workflow = graph.compile(checkpointer = InMemorySaver())

# %%
workflow

# %%
try:
    out = workflow.invoke({"topic": "Write a blog on LLM Hallucinations"}, config = {"configurable": {"thread_id": "thread-1"}})
except Exception as e:
    print(e)

# %%
list(workflow.get_state_history(config = {"configurable": {"thread_id": "thread-1"}}))
# Out:
# [StateSnapshot(values={'topic': 'Write a blog on LLM Hallucinations', 'plan': Plan(blog_title='Understanding and Mitigating LLM Hallucinations', audience='Developers and engineers working with large language models and NLP systems', tone='technical and practical', tasks=[Task(id=1, title='Introduction to LLM Hallucinations', goal='Explain what LLM hallucinations are and why they matter in practical applications.', bullets=['Define LLM hallucination with concrete examples of inaccurate or fabricated outputs from popular models (e.g., GPT).', 'Describe typical scenarios where hallucinations cause failures, such as misinformation generation or erroneous code suggestions.', 'Introduce the underlying cause: the statistical nature of language prediction vs. true knowledge representation.', 'Outline the impact on reliability, user trust, and downstream applications requiring precision.', 'Set expectations for the blog’s approach: technical explanation and actionable mitigation strategies.'], target_words=250, section_type='intro'), Task(id=2, title='How and Why LLMs Hallucinate: Technical Foundations', goal='Provide a clear, technical understanding of the mechanisms leading to hallucinations in LLMs.', bullets=['Explain the language modeling objective and how predicting next tokens probabilistically can generate plausible but false outputs.', 'Introduce concepts like distributional ambiguity, token-level sampling strategies (e.g., temperature, top-k), and their impact on output accuracy.', 'Discuss the role of training data noise, gaps, and biases contributing to hallucination.', 'Use a minimal code sketch showing sampling logits leading to improbable or hallucinated token sequences.', 'Highlight edge cases where hallucinations are more frequent, such as rare knowledge domains or ambiguous prompts.'], target_words=350, section_type='core'), Task(id=3, title='Detecting and Diagnosing Hallucinations in Outputs', goal='Enable readers to systematically identify hallucinated outputs and test their LLM responses for reliability.', bullets=['Describe manual and automated methods to detect hallucinations, including fact-checking APIs and knowledge grounding.', 'Show how to design prompt tests that trigger potential hallucinations, e.g., ambiguous or fact-based queries.', 'Introduce metrics or heuristics such as perplexity spikes, semantic similarity drops, or confidence estimates to diagnose questionable responses.', 'Demonstrate integration of logging and observability tools (e.g., response timestamping, provenance metadata) to track hallucination conditions.', 'Provide debugging tips to isolate hallucination causes, including prompt variations and model parameter tuning.'], target_words=300, section_type='core'), Task(id=4, title='Common Mistakes When Addressing LLM Hallucinations', goal='Highlight frequent pitfalls developers encounter when trying to reduce hallucinations and how to avoid them.', bullets=['Attempting to silence hallucinations by overly restrictive temperature or decoding settings, which harms creativity and diversity.', 'Relying solely on fine-tuning without validating data quality or coverage, which may reinforce hallucinated patterns.', 'Ignoring prompt engineering nuances that inadvertently trigger hallucinations (e.g., vague instructions).', 'Overlooking the need for external knowledge grounding or hybrid retrieval-augmentation setups.', 'Neglecting comprehensive testing across different inputs and usage contexts before deployment.'], target_words=200, section_type='common_mistakes'), Task(id=5, title='Techniques to Mitigate LLM Hallucinations', goal='Show actionable technical strategies to reduce hallucination rates in large language models.', bullets=['Explain retrieval-augmented generation and how integrating external verified knowledge sources improves factuality.', 'Describe prompt engineering best practices, including prompt templates, instruction clarity, and chain-of-thought explanations.', 'Demonstrate use of ...
#  StateSnapshot(values={'topic': 'Write a blog on LLM Hallucinations', 'plan': Plan(blog_title='Understanding and Mitigating LLM Hallucinations', audience='Developers and engineers working with large language models and NLP systems', tone='technical and practical', tasks=[Task(id=1, title='Introduction to LLM Hallucinations', goal='Explain what LLM hallucinations are and why they matter in practical applications.', bullets=['Define LLM hallucination with concrete examples of inaccurate or fabricated outputs from popular models (e.g., GPT).', 'Describe typical scenarios where hallucinations cause failures, such as misinformation generation or erroneous code suggestions.', 'Introduce the underlying cause: the statistical nature of language prediction vs. true knowledge representation.', 'Outline the impact on reliability, user trust, and downstream applications requiring precision.', 'Set expectations for the blog’s approach: technical explanation and actionable mitigation strategies.'], target_words=250, section_type='intro'), Task(id=2, title='How and Why LLMs Hallucinate: Technical Foundations', goal='Provide a clear, technical understanding of the mechanisms leading to hallucinations in LLMs.', bullets=['Explain the language modeling objective and how predicting next tokens probabilistically can generate plausible but false outputs.', 'Introduce concepts like distributional ambiguity, token-level sampling strategies (e.g., temperature, top-k), and their impact on output accuracy.', 'Discuss the role of training data noise, gaps, and biases contributing to hallucination.', 'Use a minimal code sketch showing sampling logits leading to improbable or hallucinated token sequences.', 'Highlight edge cases where hallucinations are more frequent, such as rare knowledge domains or ambiguous prompts.'], target_words=350, section_type='core'), Task(id=3, title='Detecting and Diagnosing Hallucinations in Outputs', goal='Enable readers to systematically identify hallucinated outputs and test their LLM responses for reliability.', bullets=['Describe manual and automated methods to detect hallucinations, including fact-checking APIs and knowledge grounding.', 'Show how to design prompt tests that trigger potential hallucinations, e.g., ambiguous or fact-based queries.', 'Introduce metrics or heuristics such as perplexity spikes, semantic similarity drops, or confidence estimates to diagnose questionable responses.', 'Demonstrate integration of logging and observability tools (e.g., response timestamping, provenance metadata) to track hallucination conditions.', 'Provide debugging tips to isolate hallucination causes, including prompt variations and model parameter tuning.'], target_words=300, section_type='core'), Task(id=4, title='Common Mistakes When Addressing LLM Hallucinations', goal='Highlight frequent pitfalls developers encounter when trying to reduce hallucinations and how to avoid them.', bullets=['Attempting to silence hallucinations by overly restrictive temperature or decoding settings, which harms creativity and diversity.', 'Relying solely on fine-tuning without validating data quality or coverage, which may reinforce hallucinated patterns.', 'Ignoring prompt engineering nuances that inadvertently trigger hallucinations (e.g., vague instructions).', 'Overlooking the need for external knowledge grounding or hybrid retrieval-augmentation setups.', 'Neglecting comprehensive testing across different inputs and usage contexts before deployment.'], target_words=200, section_type='common_mistakes'), Task(id=5, title='Techniques to Mitigate LLM Hallucinations', goal='Show actionable technical strategies to reduce hallucination rates in large language models.', bullets=['Explain retrieval-augmented generation and how integrating external verified knowledge sources improves factuality.', 'Describe prompt engineering best practices, including prompt templates, instruction clarity, and chain-of-thought explanations.', 'Demonstrate use of ...
#  StateSnapshot(values={'topic': 'Write a blog on LLM Hallucinations', 'plan': Plan(blog_title='Understanding and Mitigating LLM Hallucinations', audience='Developers and engineers working with large language models and NLP systems', tone='technical and practical', tasks=[Task(id=1, title='Introduction to LLM Hallucinations', goal='Explain what LLM hallucinations are and why they matter in practical applications.', bullets=['Define LLM hallucination with concrete examples of inaccurate or fabricated outputs from popular models (e.g., GPT).', 'Describe typical scenarios where hallucinations cause failures, such as misinformation generation or erroneous code suggestions.', 'Introduce the underlying cause: the statistical nature of language prediction vs. true knowledge representation.', 'Outline the impact on reliability, user trust, and downstream applications requiring precision.', 'Set expectations for the blog’s approach: technical explanation and actionable mitigation strategies.'], target_words=250, section_type='intro'), Task(id=2, title='How and Why LLMs Hallucinate: Technical Foundations', goal='Provide a clear, technical understanding of the mechanisms leading to hallucinations in LLMs.', bullets=['Explain the language modeling objective and how predicting next tokens probabilistically can generate plausible but false outputs.', 'Introduce concepts like distributional ambiguity, token-level sampling strategies (e.g., temperature, top-k), and their impact on output accuracy.', 'Discuss the role of training data noise, gaps, and biases contributing to hallucination.', 'Use a minimal code sketch showing sampling logits leading to improbable or hallucinated token sequences.', 'Highlight edge cases where hallucinations are more frequent, such as rare knowledge domains or ambiguous prompts.'], target_words=350, section_type='core'), Task(id=3, title='Detecting and Diagnosing Hallucinations in Outputs', goal='Enable readers to systematically identify hallucinated outputs and test their LLM responses for reliability.', bullets=['Describe manual and automated methods to detect hallucinations, including fact-checking APIs and knowledge grounding.', 'Show how to design prompt tests that trigger potential hallucinations, e.g., ambiguous or fact-based queries.', 'Introduce metrics or heuristics such as perplexity spikes, semantic similarity drops, or confidence estimates to diagnose questionable responses.', 'Demonstrate integration of logging and observability tools (e.g., response timestamping, provenance metadata) to track hallucination conditions.', 'Provide debugging tips to isolate hallucination causes, including prompt variations and model parameter tuning.'], target_words=300, section_type='core'), Task(id=4, title='Common Mistakes When Addressing LLM Hallucinations', goal='Highlight frequent pitfalls developers encounter when trying to reduce hallucinations and how to avoid them.', bullets=['Attempting to silence hallucinations by overly restrictive temperature or decoding settings, which harms creativity and diversity.', 'Relying solely on fine-tuning without validating data quality or coverage, which may reinforce hallucinated patterns.', 'Ignoring prompt engineering nuances that inadvertently trigger hallucinations (e.g., vague instructions).', 'Overlooking the need for external knowledge grounding or hybrid retrieval-augmentation setups.', 'Neglecting comprehensive testing across different inputs and usage contexts before deployment.'], target_words=200, section_type='common_mistakes'), Task(id=5, title='Techniques to Mitigate LLM Hallucinations', goal='Show actionable technical strategies to reduce hallucination rates in large language models.', bullets=['Explain retrieval-augmented generation and how integrating external verified knowledge sources improves factuality.', 'Describe prompt engineering best practices, including prompt templates, instruction clarity, and chain-of-thought explanations.', 'Demonstrate use of ...
#  StateSnapshot(values={'topic': 'Write a blog on LLM Hallucinations', 'sections': []}, next=('orchestrator',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f1099cb-376e-6b16-8000-90c9844444eb'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-02-14T12:00:05.565928+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f1099cb-376d-675d-bfff-20d7d04c9cf2'}}, tasks=(PregelTask(id='5f68864f-3702-87b0-358f-82e20871536d', name='orchestrator', path=('__pregel_pull', 'orchestrator'), error=None, interrupts=(), state=None, result={'plan': Plan(blog_title='Understanding and Mitigating LLM Hallucinations', audience='Developers and engineers working with large language models and NLP systems', tone='technical and practical', tasks=[Task(id=1, title='Introduction to LLM Hallucinations', goal='Explain what LLM hallucinations are and why they matter in practical applications.', bullets=['Define LLM hallucination with concrete examples of inaccurate or fabricated outputs from popular models (e.g., GPT).', 'Describe typical scenarios where hallucinations cause failures, such as misinformation generation or erroneous code suggestions.', 'Introduce the underlying cause: the statistical nature of language prediction vs. true knowledge representation.', 'Outline the impact on reliability, user trust, and downstream applications requiring precision.', 'Set expectations for the blog’s approach: technical explanation and actionable mitigation strategies.'], target_words=250, section_type='intro'), Task(id=2, title='How and Why LLMs Hallucinate: Technical Foundations', goal='Provide a clear, technical understanding of the mechanisms leading to hallucinations in LLMs.', bullets=['Explain the language modeling objective and how predicting next tokens probabilistically can generate plausible but false outputs.', 'Introduce concepts like distributional ambiguity, token-level sampling strategies (e.g., temperature, top-k), and their impact on output accuracy.', 'Discuss the role of training data noise, gaps, and biases contributing to hallucination.', 'Use a minimal code sketch showing sampling logits leading to improbable or hallucinated token sequences.', 'Highlight edge cases where hallucinations are more frequent, such as rare knowledge domains or ambiguous prompts.'], target_words=350, section_type='core'), Task(id=3, title='Detecting and Diagnosing Hallucinations in Outputs', goal='Enable readers to systematically identify hallucinated outputs and test their LLM responses for reliability.', bullets=['Describe manual and automated methods to detect hallucinations, including fact-checking APIs and knowledge grounding.', 'Show how to design prompt tests that trigger potential hallucinations, e.g., ambiguous or fact-based queries.', 'Introduce metrics or heuristics such as perplexity spikes, semantic similarity drops, or confidence estimates to diagnose questionable responses.', 'Demonstrate integration of logging and observability tools (e.g., response timestamping, provenance metadata) to track hallucination conditions.', 'Provide debugging tips to isolate hallucination causes, including prompt variations and model parameter tuning.'], target_words=300, section_type='core'), Task(id=4, title='Common Mistakes When Addressing LLM Hallucinations', goal='Highlight frequent pitfalls developers encounter when trying to reduce hallucinations and how to avoid them.', bullets=['Attempting to silence hallucinations by overly restrictive temperature or decoding settings, which harms creativity and diversity.', 'Relying solely on fine-tuning without validating data quality or coverage, which may reinforce hallucinated patterns.', 'Ignoring prompt engineering nuances that inadvertently trigger hallucinations (e.g., vague instructions).', 'Overlooking the need for external knowledge grounding or hybrid retrieval-augmentation setups.', 'Neglecting  ...
#  StateSnapshot(values={'sections': []}, next=('__start__',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f1099cb-376d-675d-bfff-20d7d04c9cf2'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-02-14T12:00:05.565423+00:00', parent_config=None, tasks=(PregelTask(id='89235db8-b05a-d6dd-098c-2b74364f352b', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'Write a blog on LLM Hallucinations'}),), interrupts=())]
